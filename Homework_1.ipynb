# %% [markdown]
# <a href="https://colab.research.google.com/github/Zurkon35/DSCI401/blob/main/Homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
cubs = pd.read_csv("https://raw.githubusercontent.com/gjm112/DSCI401/main/data/cubs_all_time.csv")
print(type(cubs))
print(type(cubs.Tm))
cubs.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
#    Year            Tm          Lg    G   W   L  Ties   W-L%  pythW-L%  \
# 0  2022  Chicago Cubs  NL Central  125  54  71     0  0.432     0.436
# 1  2021  Chicago Cubs  NL Central  162  71  91     0  0.438     0.421
# 2  2020  Chicago Cubs  NL Central   60  34  26     0  0.567     0.545
# 3  2019  Chicago Cubs  NL Central  162  84  78     0  0.519     0.558
# 4  2018  Chicago Cubs  NL Central  163  95  68     0  0.583     0.575
#
#      Finish  ...         Playoffs    R   RA  Attendance  BatAge  PAge  #Bat  \
# 0  3rd of 5  ...              NaN  518  596   2163550.0    28.1  29.8    57
# 1  4th of 5  ...              NaN  705  839   1978934.0    29.1  29.4    69
# 2  1st of 5  ...  Lost NLWC (2-0)  265  240         NaN    27.9  30.3    47
# 3  3rd of 5  ...              NaN  814  717   3094865.0    27.7  31.1    52
# 4  2nd of 5  ...  Lost NLWC (1-0)  761  645   3181089.0    27.2  30.2    50
#
# ...

# %%
cubs[["W","Tm"]]
# Out:
#       W                       Tm
# 0    54             Chicago Cubs
# 1    71             Chicago Cubs
# 2    34             Chicago Cubs
# 3    84             Chicago Cubs
# 4    95             Chicago Cubs
# ..   ..                      ...
# 142  67  Chicago White Stockings
# 143  46  Chicago White Stockings
# 144  30  Chicago White Stockings
# 145  26  Chicago White Stockings
# 146  52  Chicago White Stockings
#
# [147 rows x 2 columns]

# %%
win_sum = sum(cubs['W'])
print(win_sum)
# Out:
# 11141

# %%
loss_sum = sum(cubs['L'])
print(loss_sum)
# Out:
# 10592

# %%
max_runs = max(cubs['R'])
print(max_runs)
# Out:
# 1056

# %%
cubs.loc[cubs["R"].idxmax()]
# Out:
# Year                      1894
# Tm               Chicago Colts
# Lg                          NL
# G                          137
# W                           57
# L                           75
# Ties                         5
# W-L%                     0.432
# pythW-L%                  0.49
# Finish               8th of 12
# GB                        34.0
# Playoffs                   NaN
# R                         1056
# RA                        1080
# Attendance            239000.0
# BatAge                    27.3
# PAge                      26.6
# #Bat                        22
# #P                           9
# Top Player    C.Griffith (5.9)
# Managers       C.Anson (57-75)
# Name: 128, dtype: object

# %%
cubs.loc[cubs["R"].idxmin()]
# Out:
# Year                     2020
# Tm               Chicago Cubs
# Lg                 NL Central
# G                          60
# W                          34
# L                          26
# Ties                        0
# W-L%                    0.567
# pythW-L%                0.545
# Finish               1st of 5
# GB                         --
# Playoffs      Lost NLWC (2-0)
# R                         265
# RA                        240
# Attendance                NaN
# BatAge                   27.9
# PAge                     30.3
# #Bat                       47
# #P                         26
# Top Player    Y.Darvish (2.8)
# Managers       D.Ross (34-26)
# Name: 2, dtype: object

# %% [markdown]
# Covid caused the season to be short and because of this, less runs are going to occur because of this.

# %%
cubs[cubs["Attendance"] >=3000000]
# Out:
#     Year            Tm          Lg    G    W   L  Ties   W-L%  pythW-L%  \
# 3   2019  Chicago Cubs  NL Central  162   84  78     0  0.519     0.558
# 4   2018  Chicago Cubs  NL Central  163   95  68     0  0.583     0.575
# 5   2017  Chicago Cubs  NL Central  162   92  70     0  0.568     0.576
# 6   2016  Chicago Cubs  NL Central  162  103  58     1  0.640     0.665
# 11  2011  Chicago Cubs  NL Central  162   71  91     0  0.438     0.434
# 12  2010  Chicago Cubs  NL Central  162   75  87     0  0.463     0.448
# 13  2009  Chicago Cubs  NL Central  161   83  78     0  0.516     0.523
# 14  2008  Chicago Cubs  NL Central  161   97  64     0  0.602     0.609
# 15  2007  Chicago Cubs  NL Central  162   85  77     0  0.525     0.539
# 16  2006  Chicago Cubs  NL Central  162   66  96     0  0.407     0.431
# 17  2005  Chicago Cubs  NL Central  162   79  83     0  0.488     0.493
# 18  2004  Chicago Cubs  NL Central  162   89  73     0  0.549     0.578
#
# ...
